# %%
y_time = [0.0, 0,  0.009727954864501953,0.08646535873413086, 0.8105175495147705]
x_n = [10,100,1000,10000,100000]

y_time_wc = [7.152557373046875e-05, 0.021478652954101562,0.5024268627166748, 70.59147930145264 ]
x_n_wc = [10,100,1000,10000]


y_time_bf = [0,0.0030515193939208984,0.4607582092285156, 69.3634717464447 ]
x_n_bf = [10,100,1000,10000]

# %%
# importing required modules
import matplotlib.pyplot as plt
import numpy as np

# function to generate coordinates
def create_plot(ptype):
	# setting the x-axis values
	x = np.arange(0, 10000, 0.01)
	
	# setting the y-axis values
	if ptype == 'linear':
		y = x
	elif ptype == 'quadratic':
		y = .000002*x**2
	elif ptype == 'cubic':
		y = x**3
	elif ptype == 'quartic':
		y = x**4
			
	return(x, y)

# setting a style to use
plt.style.use('fivethirtyeight')

# create a figure
fig = plt.figure()

# define subplots and their positions in figure
plt1 = fig.add_subplot()

x, y = create_plot('quadratic')
plt1.plot(x, y, color ='b',label="O($n^2$)")
plt1.set_title('Minimum Manhattan Distance Runtime')

plt.plot(x_n, y_time, color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Average Case")

plt.plot(x_n_wc, y_time_wc, color='green', marker='x', linestyle='dashed',linewidth=2, markersize=12, label="Worst Case")

plt.plot(x_n_bf, y_time_bf, color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12, label= "Brute Force")

# adjusting space between subplots
fig.subplots_adjust(hspace=.5,wspace=0.5)
plt.legend(loc="upper right")
plt.xlabel("Length of Points Array")
plt.ylabel("Time taken (seconds)")
# function to show th
# Out:
# Text(0, 0.5, 'Time taken (seconds)')

# %%
# importing required modules
import matplotlib.pyplot as plt
import numpy as np

# function to generate coordinates
def create_plot(ptype):
	# setting the x-axis values
	x = np.arange(0, 10000, 0.01)
	
	# setting the y-axis values
	if ptype == 'linear':
		y = x
	elif ptype == 'quadratic':
		y = .000002*x**2
	elif ptype == 'cubic':
		y = x**3
	elif ptype == 'quartic':
		y = x**4
			
	return(x, y)

# setting a style to use
plt.style.use('fivethirtyeight')

# create a figure
fig = plt.figure()

# define subplots and their positions in figure
plt1 = fig.add_subplot()

x, y = create_plot('quadratic')
plt1.plot(x, y, color ='b',label="O($n^2$)")
plt1.set_title('Minimum Manhattan Distance Runtime')

plt.plot(x_n[0:-1], y_time[0:-1], color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Average Case")

plt.plot(x_n_wc, y_time_wc, color='green', marker='x', linestyle='dashed',linewidth=2, markersize=12, label="Worst Case")

plt.plot(x_n_bf, y_time_bf, color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12, label= "Brute Force")

# adjusting space between subplots
fig.subplots_adjust(hspace=.5,wspace=0.5)
plt.legend(loc="upper left")
plt.xlabel("Length of Points Array")
plt.ylabel("Time taken (seconds)")
# function to show the plot
plt.show()
